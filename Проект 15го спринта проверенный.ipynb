# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Владислав, привет!
#
# Меня зовут Сергей, и я буду делать ревью твоего проекта. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом. Моя основная цель - не указать тебе на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
#
# </div>

# %% [markdown]
# # Поиска инсайтов и точек роста
#
# **Автор: Черных Владислав**
#
# **Дата: 29.07.2025**
#
# С данными сервиса доставки еды «Всё.из.кафе» вы уже работали в одном из проектов базового курса. Тогда вы описывали ключевые метрики продукта — количество пользователей, заказов и выручку.
#
# Однако конкуренты сервиса не дремлют, и руководство ждёт от продукта роста. Найти инсайты, которые позволят сервису повысить показатель удержания пользователей и улучшить взаимодействие с партнёрами, поручено продуктовому аналитику, то есть вам.
#
# Вам необходимо помочь бизнесу ответить на следующие вопросы:
# - Как ведут себя пользователи? Как наиболее эффективно выстроить работу с ними, чтобы они продолжали пользоваться продуктом?
# - Какой путь проходят пользователи в сервисе? Где «проваливаются»?
# - Как улучшить взаимодействие с партнёрами-ресторанами?
#
# ### Задачи
#
# В рамках данного проекта вы проведёте комплексный анализ данных:
# - изучите пользовательский путь и проанализируете конверсии через воронки;
# - сегментируете пользователей с помощью RFM-модели для оценки лояльности и поведения клиентов;
# - кластеризуете рестораны методом K-Means, чтобы выделить группы с разными моделями работы и разработать персонализированные маркетинговые стратегии.
#
# Такой подход позволит ближе познакомиться с работой сервиса, выявить узкие места и предложить решения для удержания пользователей и повышения эффективности сотрудничества с ресторанами.
#
#
# ### Данные
#
# Данные включают следующие сведения:
#
# - `visitor_uuid` — идентификатор посетителя. Это идентификатор, который присваивается системой любому новому пользователю вне зависимости от того, зарегистрировался он в продукте или нет.
# - `user_id` — идентификатор зарегистрированного пользователя. Присваивается посетителю после создания учётной записи: ввода логина, пароля, адреса доставки и контактных данных.
# - `device_type` — тип платформы, с которой посетитель зашёл в продукт.
# - `city_id` — город, из которого посетитель зашёл в сервис.
# - `source` — рекламный источник привлечения посетителя.
# - `first_date` — дата первого посещения продукта.
# - `visit_id` — уникальный идентификатор сессии.
# - `event` — название аналитического события.
# - `datetime` — дата и время события.
# - `rest_id` — уникальный идентификатор ресторана (заполняется для заказов, карточек ресторанов и блюд).
# - `object_id` — уникальный идентификатор блюда (заполняется для заказов и карточек блюд).
# - `order_id` — уникальный идентификатор заказа.
# - `revenue` — выручка от заказа (в рублях). Это та сумма, которую пользователь видит при оплате.
# - `delivery` — стоимость доставки (в рублях).
# - `commission` — комиссия, которую «Всё.из.кафе» берёт с выручки ресторана, в процентах.
#
#
# ### План проекта
# - Загрузка данных и их предобработка.
# - Анализ пользовательского пути новых пользователей.
# - RFM сегментация.
# - K-Means кластеризация.
# - Итоговый вывод и рекомендации.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Хорошо, что есть описание и цели проекта.
# </div>

# %% [markdown]
# ## 1. Загрузка данных и их предобработка
#
# Загрузите данные и получите первую информацию о них. Проведите необходимую предобработку. Основную информацию о данных и этапы предобработки зафиксируйте в кратком промежуточном выводе.

# %%
# Импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Выгружаем датафрейм, парсим даты
df=pd.read_csv('https://code.s3.yandex.net/datasets/insides_data.csv', parse_dates=['first_date', 'datetime'])
# Выводим основную инофрмацию
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205510 entries, 0 to 205509
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   visitor_uuid  205510 non-null  object
#  1   user_id       205510 non-null  float64
#  2   device_type   205510 non-null  object
#  3   city_id       205510 non-null  int64
#  4   source        205510 non-null  object
#  5   first_date    205510 non-null  datetime64[ns]
#  6   visit_id      205510 non-null  int64
#  7   event         205510 non-null  object
#  8   datetime      205510 non-null  datetime64[ns]
#  9   rest_id       166915 non-null  object
#  10  object_id     21308 non-null   float64
#  11  order_id      7008 non-null    float64
#  12  revenue       7008 non-null    float64
#  13  delivery      7008 non-null    float64
#  14  commission    21308 non-null   float64
# dtypes: datetime64[ns](2), float64(6), int64(2), object(5)
# memory usage: 23.5+ MB

# %%
# Посмотрим часть данных
df.tail()
# Out:
#                                 visitor_uuid   user_id device_type  city_id  \
# 205505  fa03bc4e-a8d6-45b2-9df0-29e6e8449fd8  641931.0     Desktop        6
# 205506  fa03bc4e-a8d6-45b2-9df0-29e6e8449fd8  641931.0     Desktop        6
# 205507  fbf7a714-cb1d-492a-ae30-b45d02b44989  616472.0     Desktop        6
# 205508  fbf7a714-cb1d-492a-ae30-b45d02b44989  616472.0     Desktop        6
# 205509  fbf7a714-cb1d-492a-ae30-b45d02b44989  616472.0     Desktop        6
#
#          source first_date   visit_id          event            datetime  \
# 205505  organic 2021-06-28  193825829  authorization 2021-07-01 14:02:36
# 205506  organic 2021-06-28  193825829      main_page 2021-07-01 14:22:00
# 205507  organic 2021-07-01  193987971          login 2021-07-02 00:11:57
# 205508  organic 2021-07-01  193987971    add_to_cart 2021-07-02 00:12:05
# 205509  organic 2021-07-01  193987971          order 2021-07-02 00:12:08
#
# ...

# %%
# Посмотрим на временной промежуток
print(f'''Минимальная дата first_date: {df['first_date'].min()}
Максимальная дата first_date: {df['first_date'].max()}
Минимальная дата datetime: {df['datetime'].min()}
Максимальная дата datetime: {df['datetime'].max()}
''')
# Out:
# Минимальная дата first_date: 2021-04-30 00:00:00
# Максимальная дата first_date: 2021-07-01 00:00:00
# Минимальная дата datetime: 2021-05-01 00:10:55
# Максимальная дата datetime: 2021-07-02 00:12:08

# %%
# Посмотрим детально на каналы привлечения
df['source'].value_counts()
# Out:
# organic     101565
# Source_B     61435
# Source_C     32558
# Source_A      9952
# Name: source, dtype: int64

# %%
# Посмотрим виды событий
df['event'].value_counts()
# Out:
# main_page        145607
# login             18581
# object_page       12132
# authorization      9983
# reg_page           5684
# add_to_cart        5627
# confirm_phone      4347
# order              3549
# Name: event, dtype: int64

# %%
df['device_type'].value_counts()
# Out:
# Desktop    159119
# Mobile      46391
# Name: device_type, dtype: int64

# %%
# Посмотрим распределение выручки, стоимости доставки и комиссии
df[['revenue', 'delivery', 'commission']].describe()
# Out:
#             revenue     delivery    commission
# count   7008.000000  7008.000000  21308.000000
# mean    2522.338903    24.539212      0.055926
# std     2187.799948     8.652113      0.012107
# min      235.200000     9.900000      0.040000
# 25%     1316.000000    17.000000      0.050000
# 50%     1944.600000    24.200000      0.050000
# 75%     3150.000000    32.100000      0.060000
# max    42000.000000    39.900000      0.110000

# %% [markdown]
# Выручка в 42000 рублей выглядит подозрительно завышенным значением. Посмотрим детально на эти заказы

# %%
df[df['revenue']==df['revenue'].max()]
# Out:
#                                 visitor_uuid   user_id device_type  city_id  \
# 100085  d87b65b5-7bfb-4fe0-98b8-089b5ca26e84  601625.0     Desktop        6
# 100086  d87b65b5-7bfb-4fe0-98b8-089b5ca26e84  601625.0     Desktop        6
# 152088  20dc878b-332d-445e-8e42-2900c081a63f  618924.0     Desktop        6
# 152089  20dc878b-332d-445e-8e42-2900c081a63f  618924.0     Desktop        6
#
#           source first_date   visit_id        event            datetime  \
# 100085  Source_C 2021-05-21  180468230  add_to_cart 2021-06-01 06:09:47
# 100086  Source_C 2021-05-21  180468230        order 2021-06-01 06:09:50
# 152088   organic 2021-06-13  186050227  add_to_cart 2021-06-13 08:54:21
# 152089   organic 2021-06-13  186050227        order 2021-06-13 08:54:24
#
#                                  rest_id  object_id  order_id  revenue  \
# 100085  8d4f8073da2945c6bd8615fa95c74852    27810.0  627763.0  42000.0
# 100086  8d4f8073da2945c6bd8615fa95c74852    27810.0  627763.0  42000.0
# ...

# %% [markdown]
# Два разных пользователя совершили два заказа в разных ресторанах. К сожалению, данных для проверки доставерности заказа на 42000руб не хватает. Оставим датафрейм без изменений.

# %%
# Проверяем дублирующиеся строки
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [visitor_uuid, user_id, device_type, city_id, source, first_date, visit_id, event, datetime, rest_id, object_id, order_id, revenue, delivery, commission]
# Index: []

# %% [markdown]
# ### Промежуточные выводы:
# - датафрейм имеет 205 510 строк и 14 столбцов. Тип данных, наименование столбцов корректны. Дубликаты отсутствуют
# - данные представлены за период 30.04.2021 по 02.07.2021. Наименование каналов, устройства и событий в столбцах `source`, `device_type` и `event` корректны.
# - пропуски присутствуют в столбцах `rest_id`, `object_id`, `order_id`, `revenue`, `delivery` и `commission`, что характерно, так как эти столбцы заполняются для заказов и карточек блюд.
# - *датафрейм изменениям не подвергался.*

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️  Данные загружены, хорошо, что сразу меняешь неверный формат даты.
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий тимлида</b>
#
#   ⚠️ Можно еще проверить данные на неявные дубликаты (например, по полям `'user_id','datetime','event'`).
#
# </div>

# %% [markdown]
# ---
#
# ## 2. Анализ пользовательского пути
#
# Маркетологи стали замечать следующее: деньги на рекламу по-прежнему тратятся, а заказов стало меньше. И это несмотря на то, что приложение скачивается и устанавливается так же активно, как раньше. Складывается ощущение, что пользователи где-то теряются. При этом доля заказов с десктопной версии приложения увеличилась по сравнению с мобильной.
#
# Разработчики говорят, что последние обновления мобильной версии приложения не должны были повлиять на каталог блюд или его выбор для заказа и последующей оплаты доставки, так как изменения касались нового алгоритма подтверждения мобильного телефона и адреса доставки.
#
# С помощью воронок изучите общий пользовательский путь новых пользователей, затем сравните поведение пользователей мобильной и десктопной версий приложения.

# %% [markdown]
# **Задача 2.1.** Постройте и визуализируйте общую воронку (по всем данным), затем опишите пользовательский путь: какие этапы представлены, какова их последовательность, на каком (или на каких) этапах теряется большая часть новых пользователей.
#
# При решении постройте две воронки:
# - **классическую воронку** — доля от первого шага в процентах
# - **step-by-step** — с конверсией от предыдущего этапа.
#
# Предполагается, что пользователь проходит такой путь к оформлению доставки блюда из ресторанов:
# 1. `authorization` — авторизация пользователя — запуск приложения.
# 2. `main_page` — загрузка основной страницы приложения.
# 2. `reg_page` — переход на страницу регистрации.
# 2. `confirm_phone` — подтверждение телефона (окончание процесса регистрации).
# 2. `object_page` — страница блюда.
# 2. `add_to_cart` — переход в корзину.
# 2. `order` — оформление заказа.

# %%
# Создаем список с правильной последовательностью событий пользователя
funnel_steps=['authorization', 'main_page', 'reg_page', 'confirm_phone', 'object_page', 'add_to_cart', 'order']
# Строим таблицу с количеством пользователей на каждом шаге
df_funnel=df.groupby('event')['visitor_uuid'].nunique().reindex(funnel_steps).reset_index(name='count_visitors')
# Считаем классическую конверсию (доля от первого шага в процентах)
df_funnel['classic_conversion']=df_funnel['count_visitors']/df_funnel['count_visitors'][0]*100
# Считаем воронку step-by-step (конверсия от предыдущего этапа)
df_funnel['step_conversion']=df_funnel['count_visitors']/df_funnel['count_visitors'].shift(1)*100
df_funnel
# Out:
#            event  count_visitors  classic_conversion  step_conversion
# 0  authorization            7796          100.000000              NaN
# 1      main_page            6835           87.673166        87.673166
# 2       reg_page            5649           72.460236        82.648135
# 3  confirm_phone            4347           55.759364        76.951673
# 4    object_page            3530           45.279631        81.205429
# 5    add_to_cart            2929           37.570549        82.974504
# 6          order            2432           31.195485        83.031751

# %%
# Визуализируем классическую воронку

plt.figure(figsize=(10, 8))

plt.bar(df_funnel['event'], df_funnel['classic_conversion'])

plt.title('Классическая конверсия', fontsize=16, fontdict={'fontweight':'bold'})
plt.ylabel('Конверсия от первого этапа (%)', fontsize=12, fontdict={'fontweight':'bold'})
plt.tight_layout()
plt.grid(axis='y', alpha=0.4)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ На графиках стоит подписать столбцы числовыми значениями в %
# </div>

# %%
# Визуализируем воронку Step by step

plt.figure(figsize=(10, 8))

plt.bar(df_funnel['event'], df_funnel['step_conversion'])

plt.title('Step by step: конверсия от предыдущего этапа', fontsize=16, fontdict={'fontweight':'bold'})
plt.ylabel('Конверсия от предыдущего этапа (%)', fontsize=12, fontdict={'fontweight':'bold'})
plt.tight_layout()
plt.ylim(40, 100)
plt.grid(axis='y', alpha=0.4)
plt.show()

# %% [markdown]
# *Таким образом, можно увидеть что больше всего теряется пользователей на этапе подтверждения номера телефона (порядка 24% пользователей уходят). Переход с одного шага на другой на ранзных этапах использования продукта составляет 81-87%.*

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Воронки построили, верно найден основной этап, на котором идет просадка пользователей.
#
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Стоит отметить, что конверсия в целевое действие у нас всего около 30%
# </div>

# %% [markdown]
# **Задача 2.2.** Сравните пользовательский путь в двух приложениях: в мобильной версии и десктопной. Для этого постройте и визуализируйте **две воронки step-by-step**: для новых пользователей **мобильной** и **десктопной** версий приложения.
#
# Сравните результаты между собой и проанализируйте, есть ли различия в пользовательском пути для различных приложений. Результаты сравнения опишите в небольшом **промежуточном выводе**.

# %%
# Строим таблицу с количеством пользователей на каждом шаге для КОМПЛЬЮТЕРА
df_funnel_desktop=df[df['device_type']=='Desktop'].groupby('event')['visitor_uuid'].nunique().reindex(funnel_steps).reset_index(name='count_visitors')
# Считаем классическую конверсию (доля от первого шага в процентах)
df_funnel_desktop['classic_conversion']=df_funnel_desktop['count_visitors']/df_funnel_desktop['count_visitors'][0]*100
# Считаем воронку step-by-step (конверсия от предыдущего этапа)
df_funnel_desktop['step_conversion']=df_funnel_desktop['count_visitors']/df_funnel_desktop['count_visitors'].shift(1)*100
#df_funnel
df_funnel_desktop
# Out:
#            event  count_visitors  classic_conversion  step_conversion
# 0  authorization            4938          100.000000              NaN
# 1      main_page            4463           90.380721        90.380721
# 2       reg_page            3546           71.810450        79.453283
# 3  confirm_phone            3197           64.742811        90.157924
# 4    object_page            2709           54.860267        84.735690
# 5    add_to_cart            2217           44.896719        81.838317
# 6          order            1821           36.877278        82.138024

# %%
# Строим таблицу с количеством пользователей на каждом шаге для МОБИЛЬНЫХ УСТРОЙСТВ
df_funnel_mobile=df[df['device_type']=='Mobile'].groupby('event')['visitor_uuid'].nunique().reindex(funnel_steps).reset_index(name='count_visitors')
# Считаем классическую конверсию (доля от первого шага в процентах)
df_funnel_mobile['classic_conversion']=df_funnel_mobile['count_visitors']/df_funnel_mobile['count_visitors'][0]*100
# Считаем воронку step-by-step (конверсия от предыдущего этапа)
df_funnel_mobile['step_conversion']=df_funnel_mobile['count_visitors']/df_funnel_mobile['count_visitors'].shift(1)*100
#df_funnel
df_funnel_mobile
# Out:
#            event  count_visitors  classic_conversion  step_conversion
# 0  authorization            2858          100.000000              NaN
# 1      main_page            2372           82.995101        82.995101
# 2       reg_page            2103           73.582925        88.659359
# 3  confirm_phone            1150           40.237929        54.683785
# 4    object_page             821           28.726382        71.391304
# 5    add_to_cart             712           24.912526        86.723508
# 6          order             611           21.378586        85.814607

# %%
# Визуализируем классическую воронку для компьютеров

plt.figure(figsize=(10, 8))

plt.bar(df_funnel_desktop['event'], df_funnel_desktop['classic_conversion'])

plt.title('Классическая конверсия для DESKTOP', fontsize=16, fontdict={'fontweight':'bold'})
plt.ylabel('Конверсия от первого этапа (%)', fontsize=12, fontdict={'fontweight':'bold'})
plt.tight_layout()
plt.grid(axis='y', alpha=0.4)
plt.show()

# %%
# Визуализируем воронку Step by step для компьютеров

plt.figure(figsize=(10, 8))

plt.bar(df_funnel_desktop['event'], df_funnel_desktop['step_conversion'])

plt.title('Step by step: конверсия от предыдущего этапа для DESKTOP', fontsize=16, fontdict={'fontweight':'bold'})
plt.ylabel('Конверсия от предыдущего этапа (%)', fontsize=12, fontdict={'fontweight':'bold'})
plt.tight_layout()
plt.ylim(40, 100)
plt.grid(axis='y', alpha=0.4)
plt.show()

# %%
# Визуализируем классическую воронку для мобильных устройств

plt.figure(figsize=(10, 8))

plt.bar(df_funnel_mobile['event'], df_funnel_mobile['classic_conversion'])

plt.title('Классическая конверсия для MOBILE', fontsize=16, fontdict={'fontweight':'bold'})
plt.ylabel('Конверсия от первого этапа (%)', fontsize=12, fontdict={'fontweight':'bold'})
plt.tight_layout()
plt.grid(axis='y', alpha=0.4)
plt.show()

# %%
# Визуализируем воронку Step by step для мобильных устройств

plt.figure(figsize=(10, 8))

plt.bar(df_funnel_mobile['event'], df_funnel_mobile['step_conversion'])

plt.title('Step by step: конверсия от предыдущего этапа для MOBILE', fontsize=16, fontdict={'fontweight':'bold'})
plt.ylabel('Конверсия от предыдущего этапа (%)', fontsize=12, fontdict={'fontweight':'bold'})
plt.tight_layout()
plt.ylim(40, 100)
plt.grid(axis='y', alpha=0.4)
plt.show()

# %% [markdown]
# ### Промежуточные выводы:
# - Пользовательский путь в **декстопной версии** приложения практически равномерен – на каждом этапе отваливается 10-20% пользователей (больше всего отваливается на третьем этапе – переход на страницу регистрации). *Из всех пользователей (4,9к) покупки совершают 37% (1,8к).*
# - **Большинство пользователей в мобильной версии приложения отсеивается на этапе подтверждения телефона (уходит половина пользователей от прошлого этапа)**, а также на этапе просмотра страницы блюда (около 30%). Таким образом, от начала до оформления заказа через телефон доходит только *21% пользователей (с 2858 человек до 611 чел.).*
# - ***Рекомендуется вернуть старый алгоритм подтверждения мобильного телефона и адреса доставки, либо детально рассмотреть на возможность багов на данном этапе. Также рекомендуется сделать кнопки с переходом на страницу регистрации или на страницу блюда более читабельными, визуально красивыми для повышения конверсии этих этапов.***

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Верно, для мобильной версии есть снижение на шаге подтверждения телефона и возможные технические проблемы с этим. Но вот дальше, особенно на стадии оформления заказа, значения лучше. Т.е. есть зона роста для десктопной версии приложения.
#
# </div>

# %% [markdown]
# ---
#
# ## 3. RFM сегментация
#
# У сервиса доставки еды не такое высокое удержание пользователей: в первый день возвращается около 14% посетителей, а на седьмой день и того меньше — около 4–5%. Маркетологи хотят запустить несколько рекламных кампаний, направленных на удержание платящих пользователей и их возврат в сервис, если они давно не совершали заказы.
#
# Для этого необходимо сегментировать пользователей на различные поведенческие сегменты с помощью RFM-сегментации по трём показателям:
# - **давность** (Recency),
# - **частота покупок** (Frequency),
# - **сумма трат** (Monetary).
#
# В качестве даты анализа установите **03 июля 2021 года**.

# %% [markdown]
# **Задача 3.1.** Для каждого покупателя посчитайте:
# - количество дней с последней покупки — давность (R);
# - частоту покупок (F);
# - стоимость всех покупок — сумму трат (M).
#
# В качестве даты анализа установите **03 июля 2021 года**. После этого постройте три гистограммы и проанализируйте их.

# %%
# Создаем столбец для подсчета количества дней с дня покупки до дня анализа
df['order_recency'] = pd.to_datetime('2021-07-03') - df['datetime']
# Группируем данные для каждого пользователя и рассчитываем данные для RFM-анализа
rfm_users=df[df['event']=='order'].groupby('visitor_uuid').agg(
recency = ('order_recency', lambda x: x.min().days),
frequency = ('order_id', 'nunique'),
monetary_value = ('revenue', 'sum')
).reset_index()

rfm_users.head()
# Out:
#                            visitor_uuid  recency  frequency  monetary_value
# 0  0009ce93-c055-4f5e-92bc-a668617ec2e7       31          1          1540.0
# 1  001dc1fe-03f5-4b50-8742-878803e5b9ea       61          1          2100.0
# 2  003247ef-86c8-43dd-b75d-856d9f1bad01       36          3         10976.0
# 3  0044a331-d6f5-4b82-a57e-7b2bf7127839       22          2          3802.4
# 4  006bceff-9ffa-4a8a-bc8d-a327bbdf9f8a       22          1          1260.0

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Верно, для анализа нужны только покупки. Это позволит избежать дублирования данных.
#
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Стоит еще проверить и отфильтровать возможные ошибки в данных по выручке: выручка с отрицательным значением или пустые значения.
# </div>

# %%
# Строим три гистограммы
fig, axes = plt.subplots(3, 1, figsize=(15, 15))

# Давность
axes[0].hist(rfm_users['recency'], bins=30)
axes[0].set_title('Recency (дни с последней покупки)')
axes[0].set_xlabel('Дни')
axes[0].set_ylabel('Количество пользователей')

# Частота
axes[1].hist(rfm_users['frequency'], bins=30)
axes[1].set_title('Frequency (число заказов)')
axes[1].set_xlabel('Количество заказов')
axes[1].set_ylabel('Количество пользователей')

# Сумма всех заказов
axes[2].hist(rfm_users['monetary_value'], bins=30)
axes[2].set_title('Monetary (стоимость заказов)')
axes[2].set_xlabel('Стоимость заказов')
axes[2].set_ylabel('Количество пользователей')

plt.show()

# %% [markdown]
# - Метрика Recency в целом распределена равномерно, имеет широкий диапазон значений (до двух месяцев). Целесообразно будет разделить на три равные группы.
# - Значительная часть (72%) пользователей совершила только один заказ (1750 человек). 18% (450 человек) совершило два заказа. И только около 10% пользователей совершило от 3х до 13 заказов. Целесообразно будет разделить пользователей на три группы: с 1 заказом, с 2 заказами, с 3 и более заказами.
# - Распределение метрики Monetary  смещено в левую сторону — резко преобладают пользователи с недорогими заказами (до 2500 руб). Из-за сильного смещения и непрерывности значений стоимости разделим пользователей на три группы по перцентилям (33й и 66й перцентили).

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Отличное решение подобрать размер корзин, исходя из данных! За этим лучше следить, особенно при работе с дискретными данными.
#
# Кстати, еще можно использовать функцию `np.arange()` из библиотеки numpy - она позволяет делать интервалы с нецелыми значениями, например, интервал для долей - `np.arange(0, 1, 0.1)`
#
#
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ При визуцализации можно еще отфильтровать выбросы - длинный хвост по выручке.
# </div>

# %% [markdown]
# **Задача 3.2.** Выделите **RFM-сегменты** и изучите распределение пользователей по ним.
#
# Примените следующие подходы к выделению RFM сегментов:
# - **Recency** — разделите на три равные группы.
# - **Frequency** —  разделите на три группы:
#     - пользователи с 1 заказом (F-сегмент с небольшим количеством заказов);
#     - пользователи с 2 заказами (F-сегмент со средним количеством заказов);
#     - пользователи с 3 и более заказами (F-сегмент с большим количеством заказов).
# - **Monetary** — разделите на три группы по 33-му и 66-му перцентилям.
#
# После этого посчитайте количество покупателей в каждом сегменте, сделайте промежуточные выводы и напишите рекомендации.

# %%
# Определяем группу пользователя по количеству дней с момента последнего заказа: 
rfm_users['R']= pd.cut(rfm_users['recency'], bins=3, labels=[3,2,1])
# Определяем группу пользователя по количеству заказов: 
rfm_users['F']= pd.cut(rfm_users['frequency'], bins=[0, 1, 2, 50], labels=[1, 2, 3])
# Определяем группу пользователя по сумме стоимости заказов: 
rfm_users['M']= pd.qcut(rfm_users['monetary_value'], q=3, labels=[1, 2, 3])
# Находим групповой RFM-индекс:
rfm_users[['R', 'F', 'M']]=rfm_users[['R', 'F', 'M']].astype('str')
rfm_users['rfm_group'] = rfm_users['R'] + rfm_users['F'] + rfm_users['M']
# Группируем данные по сегментам и считаем их размер:
rfm_group=rfm_users.groupby('rfm_group')['visitor_uuid'].nunique().reset_index(name='user_counts')
# Считаем долю пользователей в каждом сегменте:
rfm_group['user_share']=rfm_group['user_counts']/rfm_group['user_counts'].sum()*100
# Сортируем итоговую таблицу по убыванию доли пользователей
rfm_group=rfm_group.sort_values('user_share', ascending=False)
rfm_group
# Out:
#    rfm_group  user_counts  user_share
# 8        211          287   11.800987
# 0        111          252   10.361842
# 16       311          247   10.156250
# 9        212          232    9.539474
# 1        112          219    9.004934
# 17       312          194    7.976974
# 10       213          130    5.345395
# 13       223          117    4.810855
# 18       313          103    4.235197
# 15       233          102    4.194079
# 21       323           86    3.536184
# 2        113           84    3.453947
# 5        123           79    3.248355
# 23       333           67    2.754934
# 12       222           53    2.179276
# 4        122           46    1.891447
# 20       322           45    1.850329
# 7        133           43    1.768092
# 3        121           12    0.493421
# 11       221            8    0.328947
# 6        132            8    0.328947
# 19       321            7    0.287829
# 14       232            6    0.246711
# 22       332            5    0.205592

# %% [markdown]
# ### Промежуточные выводы
# Выделим несколько сегментов:
# - 211, 111, 311, 212, 112, 312 **(58% пользователей) - совершили один заказ на небольшую или среднюю сумму.** Повторный заказ они не делали, что подверждает низкое удержание. Некоторые из них совершили покупку недавно. **Рекомендуется стимулировать данных пользователей на повторную покупку (смс уведомления), может быть провести акции на распространенные блюда, типа фастфуда (так как дорогие заказы эти пользователи делать не будут).**
# - 213, 223, 313, 233, 323, 113, 123, 333 **(31,5% пользователей) - совершают дорогие заказы.** Также характерно несколько заказов и активность покупок. **Данных клиентов стоит удерживать с помощью персонализированных предложений, программ лояльности и эксклюзивных акций.**
# - 222, 122, 322, 133 **(7,5% пользователей) - делали 2 и более заказов на средние или большие суммы.** Хоть таких пользователей немного, однако они готовы совершать повторные дорогие заказы. **Следует предусмотреть для них программу лояльности, а также акции на какие-нибудь ресторанные блюда.**

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Получили сегмменты покупателей. Отличное использование методов `qcut` и `cut` для сегментации!
#
#
#
# </div>

# %% [markdown]
# ---
#
# ## 4. K-Means кластеризация
#
# Чтобы лучше понимать поведение ресторанов и предлагать им персонализированные условия сотрудничества, а также создавать персонализированные предложения для пользователей, маркетологи запросили кластеризацию ресторанов по следующим параметрам:
# - общее количество заказов;
# - средняя стоимость заказа;
# - общее число заказанных уникальных блюд (ассортимент ресторана).
#
# С помощью метода K-Means разделите рестораны на кластеры, отражающие различные модели работы и целевые сегменты. Это позволяет выделить группы ресторанов с похожими характеристиками и разрабатывать для них эффективные маркетинговые стратегии.

# %% [markdown]
# **Задача 4.1.** Подготовьте данные для кластеризации и для каждого ресторана подсчитайте:
# - общее количество заказов;
# - средняя стоимость заказа;
# - общее число заказанных уникальных блюд (ассортимент ресторана).

# %%
# создаем таблицу, где для каждого ресторана будет показано общее кол-во заказов, ср.стоимость заказа и кол-во уникальных блюд
df_rest=df[df['event']=='order'].groupby('rest_id').agg(
count_orders=('order_id', 'nunique'),
avg_revenue=('revenue', 'mean'),
count_dishes=('object_id', 'nunique')
)
df_rest.head(5)
# Out:
#                                   count_orders  avg_revenue  count_dishes
# rest_id
# 1be5a933aab34fbab594bebba48e976e           144  2260.180222            28
# 1d6bb74687104fa1953924c9684fe624           108  2959.256481            19
# 2c6095730b514c189ee41c65f03febc3             8  1673.000000             4
# 3247a3b5f9494812a3c1a73c5b61f004            33  2777.209697             4
# 39b7eab4f4704ed2886fafe171489960            33  2011.269697             5

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Параметры для кластеризации выбрали верно.
#
# </div>

# %% [markdown]
# **Задача 4.2.** Нормализуйте данные и найдите оптимальное количество кластеров, использовав метод `.inertia_`. Постройте график зависимости инерции от числа кластеров (метод «локтя») и предположите оптимальное количество кластеров.

# %%
# Нормализуем данные
X_scaled = StandardScaler().fit_transform(df_rest)

# Создаём массив, в котором будем хранить значения inertia для разбиения с разным числом кластеров
array_0= []

# Перебираем разное количество кластеров
for i in range(1, 11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit_predict(X_scaled)
    array_0.append(kmeans.inertia_)

# Строим график зависимости инерции от количества кластеров
plt.figure(figsize=(12, 8))
plt.plot(range(1, 11), array_0, marker='o')
plt.xlabel('Число кластеров')
plt.ylabel('Суммарное внутрикластерное расстояние (Inertia)')
plt.title('График зависимости инерции от числа кластеров (метод локтя)')
plt.show()

# %%
X_scaled.std()
# Out:
# 0.9999999999999999

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#  ⚠️ Перед применением K-Means лучше нормализовать данные, чтобы признаки с разными масштабами имели одинаковый вес при расчете расстояний.
# </div>

# %% [markdown]
# Таким образом, согласно графику и методу локтя **оптимальное количество кластеров принимаем 4.**

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Можем выделить 2-4 кластера.
#
# Пока опыта мало, лучше определять количество кластеров построив дендограмму, ориентироваться по цвету легче (код ниже).
#
# Если у нас цвет одиного кластера получается слишком большим (зеленый),  можно провести линию по шкалам и посчитать сколько пересечений: у нас тут будет не 2, как по цвету (оранжевый и зеленый), а 4 - зеленый разбиваем на 3.
# </div>

# %%
# Код ревьюера:
# Создадим таблицу связей:
from scipy.cluster.hierarchy import dendrogram, linkage

linked = linkage(X_scaled, method = 'ward')

# Визуализируем таблицу связей:
plt.figure(figsize=(7, 4))  
dendrogram(linked, orientation='top')

plt.axhline(y=1700, color='r', linestyle='--')  
plt.title("Иерархическая кластеризация (дендрограмма)")
plt.xlabel("Объекты")
plt.ylabel("Расстояние")

plt.show()

# %% [markdown]
# **Задача 4.3.** Проведите кластеризацию, проанализируйте полученные результаты и рассчитайте средние значения по каждому кластеру.
#
# После этого визуализируйте результаты, чтобы проследить зависимость признаков друг от друга. Постройте две визуализации, на которые нанесите все кластеры:
# - средний чек в зависимости от количества заказов;
# - количество блюд в зависимости от количества заказов.
#
# После этого опишите каждый кластер в промежуточном выводе.

# %%
# Определяем количество кластеров 
kmeans = KMeans(n_clusters=4, random_state=1)
labels = kmeans.fit_predict(X_scaled)

# Получаем координаты центров (центроидов) кластеров
centroids = kmeans.cluster_centers_

# Создаём 3 графика (1 строка × 2 столбца) для отображения попарных комбинаций признаков
fig, axes = plt.subplots(2, 1, figsize=(15, 12))

# Список названий признаков, которые будут использоваться на графиках
axs = ["count_orders", "avg_revenue", "count_dishes"]

# Перебираем пары признаков:
for i, (x_idx, y_idx) in enumerate([[0, 1], [0, 2]]):
   x_label, y_label = axs[x_idx], axs[y_idx]  # Названия признаков для осей

   # Строим точки — объекты из датафрейма, раскрашенные по меткам кластера
   scatter=axes[i].scatter(
       df_rest[x_label],  # Значения по оси X
       df_rest[y_label],  # Значения по оси Y
       c=labels,  # Цвет зависит от номера кластера
       cmap='viridis',  # Цветовая карта
       s=50,  # Размер точек
       label=f"Кластер {i+1}"
   )
   
   # Подписи осей и заголовок графика
   axes[i].set_xlabel(x_label)
   axes[i].set_ylabel(y_label)
   axes[i].set_title(f'{x_label} vs {y_label}')
   axes[i].legend(*scatter.legend_elements(), title='Кластер')

# Подгоняем макет, оставляя место снизу для подписи с инерцией
plt.tight_layout(rect=[0, 0.05, 1, 1])

# Показываем итоговый набор визуализаций
plt.show()

# %% [markdown]
# Тоже самое, но сделаем через библиотеку seaborn, так как легче строить легенду и графики

# %%
# Тоже самое через библбиотеку seaborn
# Делаем столбец с кластерами в исходный датафрейм
df_rest["cluster"] = labels

plt.figure(figsize=(12, 6))

sns.scatterplot(df_rest['count_orders'], df_rest['avg_revenue'], hue=labels, palette='viridis')

plt.legend(title='Кластер')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(df_rest['count_orders'], df_rest['count_dishes'], hue=labels, palette='viridis')
plt.legend(title='Кластер')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ При кластеризации стоит еще указать параметр random_state: `kmeans = KMeans(n_clusters=4, random_state=1)`. Когда мы задаем параметр random_state отличным от None - то генерируемые псевдослучайные величины будут иметь одни и те же значения при каждом вызове, т.е. при каждом запуске проекта мы будем получать одни и те-же кластеры.
#
#
# </div>

# %%
# Сортируем кластеры по возрастанию выручки avg_revenue
sorted_indices = np.argsort(kmeans.cluster_centers_[:, 1])
sorted_centroids = kmeans.cluster_centers_[sorted_indices]

# Создаём DataFrame из центроидов
centroids_df = pd.DataFrame(
   sorted_centroids,
   columns=["count_orders", "avg_revenue", "count_dishes"],
   index=[f'Кластер {i + 1}' for i in range(kmeans.n_clusters)]
)

# Форматируем числа для вывода (2 знака после точки)
pd.options.display.float_format = '{:.3f}'.format

# Выводим таблицу
print(centroids_df.head())
# Out:
#            count_orders  avg_revenue  count_dishes
# Кластер 1        -0.316       -0.712        -0.288
# Кластер 2         3.020       -0.067         2.928
# Кластер 3        -0.336        0.532        -0.265
# Кластер 4        -0.276        2.390        -0.553

# %% [markdown]
# ### Промежуточные выводы
# 1. Кластер 1 характеризуется средним количеством заказов и ассортиментом блюд, а также небольшой выручкой. Для раскрутки таких ресторанов возможно стоит снизить на какое-то время комисиию доставки.
# 2. **Кластер 2 - содержит аномально большое количество разных блюд, что способствовало огромному количеству заказов. Хоть заказов и много, выручка небольшая по сравнению с другими кластерами. Возможно связано с небольшой стоимостью блюд. С данными ресторанами стоит тесно сотрудничать, так как пользователи активно пользуются приложением, чтобы сделать доствку. Возможно стоит ввести бонусную программу с данными ресторанами.**
# 3. Кластер 3 - небольшое количество заказов, средняя выручка. Ассортимент блюд разнообразен. Аналогичен первому кластеру. Возможно стоит ввести бонусную программу, чтобы и дальше стимулировать людей на дорогие заказы.
# 4. **Кластер 4 - среднее количество заказов, самая большая выручка. Ассортимент блюд неразнообразен. Стоит обратить внимание на указанные рестораны, так как с них самая большая выручка и довольно много заказов. Для клиентов данных ресторанов можно попробовать ввести персональные предложения.**

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Изучили наши кластеры. Визуализация хорошо демонстрируют различия кластеров.
# </div>

# %% [markdown]
# ---
#
# ## 5. Итоговый вывод и рекомендации
#
# Сформулируйте общий вывод. Зафиксируйте основные результаты и инсайты, которые, на ваш взгляд, помогут бизнесу улучшить продукт.
#
# Выводы должны быть краткими и ёмкими, ведь их будут читать ваш заказчик, продуктовый менеджер и продуктовая команда.

# %% [markdown]
# - Большинство пользователей в мобильной версии приложения отсеивается на этапе подтверждения телефона, а также на этапе просмотра страницы блюда. Таким образом, от начала до оформления заказа через телефон доходит только 21% пользователей.Рекомендуется вернуть старый алгоритм подтверждения мобильного телефона и адреса доставки, либо детально рассмотреть на возможность багов на данном этапе. Также рекомендуется сделать кнопки с переходом на страницу регистрации или на страницу блюда более читабельными, визуально красивыми для повышения конверсии этих этапов.
# - Больше половины пользователей (58%) активные, но не прибыльные и невозвращающиеся. Следует застимулировать данных пользователей на повторную покупку (смс уведомления),тажкже может быть провести акции на распространенные блюда, типа фастфуда (так как дорогие заказы эти пользователи делать не будут).
# - Среди пользователей около 31,5% совершают дорогие заказы. Для них стоит ввести персонализированные предложения, программы ояльности и эксклюзивные акции.
# - Среди ресторанов следует обратить внимание на рестораны второго и четвертого кластера, так как в них совершается максимальное количество заказов (что хорошо сказывается на популярности приложения) и в этих ресторанах хорошая выручка. С ресторанами второго и четвертого кластера надо тесно сотрудничать, а для постоянных клиентов можно попробовать ввести персональные предложения.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ В итоговом выводе нам надо подробней описать результаты  RFM-сегментации (можно похожие сегменты описать сгруппировав) и K-Means кластеризации.
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Проект выполнен без критических замечаний!
#
# Рекомендую почитать статью по выбору метода сегментации,  даже по нашим данным можно попробовать разные методы: https://vaael.ru/ru/article/view?id=1596
# </div>
